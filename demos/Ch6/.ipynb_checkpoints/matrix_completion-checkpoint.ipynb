# %%
# load function that implements alternating least squares for 
# low-rank matrix completion
source("matrix_completion_fct.R")

# %%
set.seed(97871)
# generate ground truth
A <- matrix(nrow = 500, ncol = 10, data = runif(5000))
B <- t(matrix(nrow = 200, ncol = 10, data = runif(2000)))
X <- A %*% B
# generate 20% missing entries, uniformly at random
M <- sample(length(X), 10000, replace = FALSE)
X[M] <- NA

# %%
X[1:10, 1:5]
# Out:
#       [,1]     [,2]     [,3]     [,4]     [,5]
#  [1,] 2.261900 1.623007 1.973578 2.520847 1.040311
#  [2,] 2.259101       NA 2.164220 2.523501 1.115278
#  [3,] 1.892102 2.195391 2.498909 3.006631 1.549333
#  [4,] 3.204284 2.994697 3.315372 3.765637 1.954851
#  [5,] 2.832006 2.711525 3.025729 3.199231       NA
#  [6,]       NA 3.449270 3.635817 4.044453 1.962932
#  [7,] 3.008041 2.629590 3.038796 3.173282 1.722559
#  [8,] 2.629945 2.507477       NA 3.155875 1.665138
#  [9,] 2.287420 2.694588 2.654658 3.076512 1.735757
# [10,] 2.471956 2.398951 2.637956 2.780576 1.287735

# %%
### recovery of B given A, with A randomly initialized 
Ahat <- matrix(runif(500 * 10), nrow = 500, ncol = 10)
res <- ALS(X, A_init = Ahat)

# %%
# compare solution (Xhat) to ground gruth
sum(abs(res$Xhat - A %*% B))
# Out:
# [1] 13432.43
