# %%
rent <- read.csv("../../data/munich_rent/munich_rent.csv", header = TRUE)

### (1) Correlation matrix
Sigma <- cor(cbind(rent = rent$rent, area = rent$area, rooms = rent$rooms))
print(Sigma)
# Out:
#            rent      area     rooms
# rent  1.0000000 0.7074627 0.5442473
# area  0.7074627 1.0000000 0.8406454
# rooms 0.5442473 0.8406454 1.0000000

# %%
### (2) Partial correlation matrix
Sigmainv <- solve(Sigma)
PC <- -cov2cor(Sigmainv)
diag(PC) <- 1

print(PC)

### (3) Partial residual plot

#pdf("../fig/partial_regression.pdf")
plot(residuals(lm(rent~area, data =rent)), residuals(lm(rooms ~ area, data = rent)), xlab = "rent", ylab = "rooms")
#dev.off()
# Out:
#             rent      area      rooms
# rent   1.0000000 0.5501128 -0.1318768
# area   0.5501128 1.0000000  0.7684307
# rooms -0.1318768 0.7684307  1.0000000
# plot without title
